# %% [markdown]
# # Introduction
#
# The prediction of future global temperatures is a critical aspect of climate research and policy-making. By accurately forecasting temperature trends, we can gain valuable insights into the potential impacts of climate change and make informed decisions to mitigate its effects. In this study, we explore the use of ARIMA (Autoregressive Integrated Moving Average) and SARIMA (Seasonal ARIMA) models to forecast global temperature values based solely on historical temperature data.
#
# The dataset used in this analysis is sourced from Berkeley Earth, an organization affiliated with Lawrence Berkeley National Laboratory. This dataset provides comprehensive and reliable surface temperature measurements from various locations across the globe. The data can be accessed from the following Kaggle repository: https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data.
#
# The primary objective of this study is to investigate the effectiveness of ARIMA and SARIMA models in capturing the temporal patterns and predicting future global temperature changes. These models are well-suited for time series analysis, as they can account for the autocorrelation and seasonality present in the temperature data.
#
# By leveraging the historical temperature observations, we aim to develop accurate and robust forecasting models. The insights gained from these models can help us understand the long-term temperature trends, identify potential climate anomalies, and assess the efficacy of climate change mitigation strategies.

# %% [markdown]
# # EDA

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as dataL

# %%
# Importing dataset
df = pd.read_csv('/home/veroastro/Documents/Forecasting_globla_temp/data/GlobalTemperatures.csv')
df.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
# creating dataset with the relevant columns and 
    # deleting the missing values
cols = ['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty']
land_avg_temp = df[cols].dropna()
land_avg_temp.isna().sum()
# Out:
# dt                                   0
# LandAverageTemperature               0
# LandAverageTemperatureUncertainty    0
# dtype: int64

# %%
# creating the dataset of temperatures by year
land_avg_temp['years'] = pd.DatetimeIndex(land_avg_temp['dt']).year
yearly = land_avg_temp.groupby('years').mean()
print(yearly.describe())
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty
# count              266.000000                         266.000000
# mean                 8.369337                           0.945719
# std                  0.584921                           0.994110
# min                  5.779833                           0.062083
# 25%                  8.081563                           0.210208
# 50%                  8.372167                           0.405583
# 75%                  8.704167                           1.629563
# max                  9.831000                           4.026000

# %%
# Creating the dataset with only the temperatures and 
# dropping first 100 elements to reduce errors.
avg_temp = yearly['LandAverageTemperature'].drop(yearly.index[:100])
avg_temp.describe()
# Out:
# count    166.000000
# mean       8.571583
# std        0.473687
# min        7.558583
# 25%        8.195708
# 50%        8.540750
# 75%        8.791250
# max        9.831000
# Name: LandAverageTemperature, dtype: float64

# %%
# Plotting the new dataset
y = avg_temp
plt.plot(y)
plt.title("Average Land Temperature per year")
plt.xlabel("Year")
plt.ylabel("Average Temperature per year")
plt.show()

# %% [markdown]
# There is less sharp variations on the temperatures. Also the temperature seems to sharply increase since about 1960 of about 1 degree celsius.

# %% [markdown]
# # Analysis
#
# ## Data Preprocessing

# %%
# splitting the dataset into train and test datasets
size = len(avg_temp)
cutoff = int(size*0.7)
train = pd.DataFrame(avg_temp[:cutoff])
test = pd.DataFrame(avg_temp[cutoff:])
print('train:', train.shape)
print('test:', test.shape)
print('Cut-off year =', 1850+train.shape[0])
# Out:
# train: (116, 1)
# test: (50, 1)
# Cut-off year = 1966

# %%
import torch

def create_dataset(dataset, lookback):
    """Transform a time series into a prediction dataset
    
    Args:
        dataset: A numpy array of time series, first dimension is the time steps
        lookback: Size of window for prediction
    """
    X, y = [], []
    for i in range(len(dataset)-lookback):
        feature = dataset[i:i+lookback]
        target = dataset[i+1:i+lookback+1]
        X.append(feature)
        y.append(target)
    return torch.tensor(X), torch.tensor(y)

# %%
lookback = 4
X_train, y_train = create_dataset(train.to_numpy(), lookback=lookback)
X_test, y_test = create_dataset(test.to_numpy(), lookback=lookback)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([112, 4, 1]) torch.Size([112, 4, 1])
# torch.Size([46, 4, 1]) torch.Size([46, 4, 1])

# %% [markdown]
# ## Building Model

# %%
from sklearn.metrics import mean_squared_error
# Fit the naive model
naive_model_predictions = np.repeat(train.iloc[-1], len(test))

# Evaluate the model
rmse = np.sqrt(mean_squared_error(test, naive_model_predictions))
print(f"RMSE of Naive Model: {rmse:.4f}")
# Out:
# RMSE of Naive Model: 0.6863

# %%
class LSTMmodel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=50, num_layers=1, batch_first=True)
        self.linear = nn.Linear(50, 1)
    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x)
        return x

# %%
model = LSTMmodel().double()
optimizer = optim.Adam(model.parameters())
loss_fn = nn.MSELoss()
loader = dataL.DataLoader(dataL.TensorDataset(X_train, y_train), shuffle=True, batch_size=8)

# %% [markdown]
# From the plot above, the trend of the dataset has been removed.

# %%
n_epochs = 4000 
for epoch in range(n_epochs):
    model.train()
    for X_batch, y_batch in loader:
        y_pred = model(X_batch)
        loss = loss_fn(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # Validation
    if epoch % 100 != 0:
        continue
    model.eval()
    with torch.no_grad():
        y_pred = model(X_train)
        train_rmse = np.sqrt(loss_fn(y_pred, y_train))
        y_pred = model(X_test)
        test_rmse = np.sqrt(loss_fn(y_pred, y_test))
    print("Epoch %d: train RMSE %.4f, test RMSE %.4f" % (epoch, train_rmse, test_rmse))
# Out:
# Epoch 0: train RMSE 7.4536, test RMSE 8.1684
# Epoch 100: train RMSE 0.2662, test RMSE 0.7280
# Epoch 200: train RMSE 0.2165, test RMSE 0.4859
# Epoch 300: train RMSE 0.2160, test RMSE 0.4445
# Epoch 400: train RMSE 0.2096, test RMSE 0.4412
# Epoch 500: train RMSE 0.2078, test RMSE 0.3973
# Epoch 600: train RMSE 0.2015, test RMSE 0.3657
# Epoch 700: train RMSE 0.1984, test RMSE 0.3647
# Epoch 800: train RMSE 0.2135, test RMSE 0.3857
# Epoch 900: train RMSE 0.1923, test RMSE 0.3094
# Epoch 1000: train RMSE 0.1915, test RMSE 0.3113
# Epoch 1100: train RMSE 0.2005, test RMSE 0.2775
# Epoch 1200: train RMSE 0.2187, test RMSE 0.3809
# Epoch 1300: train RMSE 0.1933, test RMSE 0.2839
# Epoch 1400: train RMSE 0.1909, test RMSE 0.3021
# Epoch 1500: train RMSE 0.1917, test RMSE 0.2914
# Epoch 1600: train RMSE 0.1982, test RMSE 0.3369
# Epoch 1700: train RMSE 0.1918, test RMSE 0.2889
# Epoch 1800: train RMSE 0.1911, test RMSE 0.3118
# Epoch 1900: train RMSE 0.1920, test RMSE 0.3173
# Epoch 2000: train RMSE 0.1913, test RMSE 0.2920
# Epoch 2100: train RMSE 0.2088, test RMSE 0.2598
# Epoch 2200: train RMSE 0.1918, test RMSE 0.2863
# Epoch 2300: train RMSE 0.1905, test RMSE 0.3015
# Epoch 2400: train RMSE 0.1901, test RMSE 0.2925
# Epoch 2500: train RMSE 0.1911, test RMSE 0.2912
# Epoch 2600: train RMSE 0.1940, test RMSE 0.3222
# Epoch 2700: train RMSE 0.1918, test RMSE 0.2779
# Epoch 2800: train RMSE 0.1920, test RMSE 0.2761
# Epoch 2900: train RMSE 0.1954, test RMSE 0.3215
# Epoch 3000: train RMSE 0.1912, test RMSE 0.2807
# Epoch 3100: train RMSE 0.1902, test RMSE 0.2903
# Epoch 3200: train RMSE 0.2048, test RMSE 0.2619
# Epoch 3300: train RMSE 0.1895, test RMSE 0.2943
# Epoch 3400: train RMSE 0.1953, test RMSE 0.3300
# Epoch 3500: train RMSE 0.1952, test RMSE 0.3301
# Epoch 3600: train RMSE 0.1891, test RMSE 0.3084
# Epoch 3700: train RMSE 0.1896, test RMSE 0.3068
# Epoch 3800: train RMSE 0.1896, test RMSE 0.2991
# Epoch 3900: train RMSE 0.1900, test RMSE 0.3415

# %%
with torch.no_grad():
    # shift train predictions for plotting
    train_plot = np.ones_like(avg_temp) * np.nan
    y_pred = model(X_train)
    y_pred = y_pred[:, -1, :]
    train_pred = np.resize(model(X_train)[:, -1, :].numpy(),112)
    train_plot[lookback:cutoff] = train_pred
    # shift test predictions for plotting
    test_plot = np.ones_like(avg_temp) * np.nan
    test_pred = np.resize(model(X_test)[:, -1, :],46)
    test_plot[cutoff+lookback:len(avg_temp)] = test_pred
# plot
x_axis = np.arange(train.shape[0] + test.shape[0])
x_years = x_axis + 1850  # Year starts at 1850
plt.plot(avg_temp)
plt.plot(x_years,train_plot, c='r')
plt.plot(x_years,test_plot, c='g')
plt.show()

# %%
 with torch.no_grad():
        y_pred = model(X_train)
        train_rmse = np.sqrt(loss_fn(y_pred, y_train))
        y_pred = model(X_test)
        test_rmse = np.sqrt(loss_fn(y_pred, y_test))
        print("train RMSE %.4f, test RMSE %.4f" % (train_rmse, test_rmse))
# Out:
# train RMSE 0.1895, test RMSE 0.3063

# %% [markdown]
# ## Optimizing the model

# %%
import optuna
from optuna.trial import TrialState
def get_loader(data, batchsize):
    # 
    size = len(data)
    cutoff = int(size*0.8)

    train = pd.DataFrame(data[:cutoff])
    val= pd.DataFrame(data[cutoff:])

    X_train, y_train = create_dataset(train.to_numpy(), lookback=lookback)
    X_val, y_val= create_dataset(val.to_numpy(), lookback=lookback)
    
    train_loader = dataL.DataLoader(dataL.TensorDataset(X_train, y_train), shuffle=True, 
                                    batch_size=batchsize)
    
    valid_loader =  dataL.DataLoader(dataL.TensorDataset(X_val, y_val),
                                        batch_size=batchsize, shuffle=True,)
    
    return train_loader, valid_loader

def calculate_rmse(model, loader):
    predictions = []
    targets = []
    for X, y in loader:
        y_pred = model(X)
        predictions.append(y_pred)
        targets.append(y)

    predictions = torch.cat(predictions, dim=0)
    targets = torch.cat(targets, dim=0)
    rmse = torch.sqrt(loss_fn(predictions, targets))
    return rmse.item()


def objective(trial):
    model = LSTMmodel().double()
    optimizer_name = optim.Adam(model.parameters())#trial.suggest_categorical("optimizer", ["adam", "SGD", "RMSprop", "Adadelta"])
    epochs = trial.suggest_int("epochs", 1000, 4000,step=100, log=False)
    batchsize = 8 #trial.suggest_int("batchsize", 8, 40,step=16, log=False)
    
    
    train_loader, valid_loader = get_loader(train, batchsize)
                                  
    for epoch in range(epochs):
        model.train()
        for X_batch, y_batch in train_loader:
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Validation

        model.eval()
        with torch.no_grad():
            valid_rmse = calculate_rmse(model, valid_loader)
            
    weights = list(model.named_parameters())

    # Handle pruning based on the intermediate value.
    if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

    trial.set_user_attr(key="best_model_weights", value=weights)
    return valid_rmse

def callback(study, trial):
    if study.best_trial.number == trial.number:
        study.set_user_attr(key="best_model_weights", 
                            value=trial.user_attrs["best_model_weights"])

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10, timeout=None, callbacks=[callback])
    
pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-06-11 09:21:16,869] A new study created in memory with name: no-name-db7ad7ba-68c4-4a3c-9cc5-d53278dd202d
# [I 2023-06-11 09:22:55,248] Trial 0 finished with value: 8.593972243009732 and parameters: {'epochs': 2900}. Best is trial 0 with value: 8.593972243009732.
# [I 2023-06-11 09:23:35,657] Trial 1 finished with value: 8.686995702970357 and parameters: {'epochs': 1200}. Best is trial 0 with value: 8.593972243009732.
# [I 2023-06-11 09:25:56,079] Trial 2 finished with value: 8.646106089937058 and parameters: {'epochs': 3600}. Best is trial 0 with value: 8.593972243009732.
# [I 2023-06-11 09:26:45,087] Trial 3 finished with value: 8.562516404524278 and parameters: {'epochs': 1300}. Best is trial 3 with value: 8.562516404524278.
# [I 2023-06-11 09:27:51,360] Trial 4 finished with value: 8.78973133300857 and parameters: {'epochs': 1600}. Best is trial 3 with value: 8.562516404524278.
# [I 2023-06-11 09:30:36,226] Trial 5 finished with value: 8.539670988355349 and parameters: {'epochs': 3500}. Best is trial 5 with value: 8.539670988355349.
# [I 2023-06-11 09:32:18,113] Trial 6 finished with value: 8.363009261314026 and parameters: {'epochs': 2500}. Best is trial 6 with value: 8.363009261314026.
# [I 2023-06-11 09:33:59,198] Trial 7 finished with value: 8.654324284341907 and parameters: {'epochs': 2000}. Best is trial 6 with value: 8.363009261314026.
# [I 2023-06-11 09:35:15,836] Trial 8 finished with value: 8.526393097938321 and parameters: {'epochs': 1900}. Best is trial 6 with value: 8.363009261314026.
# [I 2023-06-11 09:37:12,106] Trial 9 finished with value: 8.648950882958326 and parameters: {'epochs': 2500}. Best is trial 6 with value: 8.363009261314026.
# Study statistics:
#   Number of finished trials:  10
#   Number of pruned trials:  0
#   Number of complete trials:  10
# Best trial:
#   Value:  8.363009261314026
#   Params:
#     epochs: 2500

# %%
print(trial.params.get("epochs"))
# Out:
# 2500

# %%
n_epochs = trial.params.get("epochs")
for epoch in range(n_epochs):
    model.train()
    for X_batch, y_batch in loader:
        y_pred = model(X_batch)
        loss = loss_fn(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # Validation
    if epoch % 100 != 0:
        continue
    model.eval()
    with torch.no_grad():
        y_pred = model(X_train)
        train_rmse = np.sqrt(loss_fn(y_pred, y_train))
        y_pred = model(X_test)
        test_rmse = np.sqrt(loss_fn(y_pred, y_test))
    print("Epoch %d: train RMSE %.4f, test RMSE %.4f" % (epoch, train_rmse, test_rmse))
# Out:
# Epoch 0: train RMSE 0.1989, test RMSE 0.3998
# Epoch 100: train RMSE 0.1994, test RMSE 0.2887
# Epoch 200: train RMSE 0.1898, test RMSE 0.3085
# Epoch 300: train RMSE 0.1876, test RMSE 0.3229
# Epoch 400: train RMSE 0.1909, test RMSE 0.3509
# Epoch 500: train RMSE 0.1922, test RMSE 0.3027
# Epoch 600: train RMSE 0.1875, test RMSE 0.3328
# Epoch 700: train RMSE 0.1873, test RMSE 0.3195
# Epoch 800: train RMSE 0.1895, test RMSE 0.3113
# Epoch 900: train RMSE 0.1868, test RMSE 0.3235
# Epoch 1000: train RMSE 0.1873, test RMSE 0.3338
# Epoch 1100: train RMSE 0.1881, test RMSE 0.3128
# Epoch 1200: train RMSE 0.1877, test RMSE 0.3378
# Epoch 1300: train RMSE 0.1890, test RMSE 0.3139
# Epoch 1400: train RMSE 0.1863, test RMSE 0.3248
# Epoch 1500: train RMSE 0.1905, test RMSE 0.3127
# Epoch 1600: train RMSE 0.1864, test RMSE 0.3403
# Epoch 1700: train RMSE 0.1868, test RMSE 0.3240
# Epoch 1800: train RMSE 0.1864, test RMSE 0.3489
# Epoch 1900: train RMSE 0.1858, test RMSE 0.3407
# Epoch 2000: train RMSE 0.1855, test RMSE 0.3458
# Epoch 2100: train RMSE 0.1859, test RMSE 0.3479
# Epoch 2200: train RMSE 0.1910, test RMSE 0.3186
# Epoch 2300: train RMSE 0.1862, test RMSE 0.3479
# Epoch 2400: train RMSE 0.1891, test RMSE 0.3794

# %%
with torch.no_grad():
    # shift train predictions for plotting
    train_plot = np.ones_like(avg_temp) * np.nan
    y_pred = model(X_train)
    y_pred = y_pred[:, -1, :]
    train_pred = np.resize(model(X_train)[:, -1, :].numpy(),112)
    train_plot[lookback:cutoff] = train_pred
    # shift test predictions for plotting
    test_plot = np.ones_like(avg_temp) * np.nan
    test_pred = np.resize(model(X_test)[:, -1, :],46)
    test_plot[cutoff+lookback:len(avg_temp)] = test_pred
# plot
x_axis = np.arange(train.shape[0] + test.shape[0])
x_years = x_axis + 1850  # Year starts at 1850
plt.plot(avg_temp)
plt.plot(x_years,train_plot, c='r')
plt.plot(x_years,test_plot, c='g')
plt.show()
